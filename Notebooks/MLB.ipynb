# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
HOF_file = "../Resources/Hall_of_Fame.csv"
HOF_file_df = pd.read_csv(HOF_file)
HOF_file_df
# Out:
#        playerID  yearid votedBy  ballots  needed  votes inducted category  \
# 0      cobbty01    1936   BBWAA    226.0   170.0  222.0        Y   Player
# 1      ruthba01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 2     wagneho01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 3     mathech01    1936   BBWAA    226.0   170.0  205.0        Y   Player
# 4     johnswa01    1936   BBWAA    226.0   170.0  189.0        Y   Player
# ...         ...     ...     ...      ...     ...    ...      ...      ...
# 4115  grudzma01    2016   BBWAA    440.0   330.0    0.0        N   Player
# 4116  ausmubr01    2016   BBWAA    440.0   330.0    0.0        N   Player
# 4117  hamptmi01    2016   BBWAA    440.0   330.0    0.0        N   Player
# 4118  castilu01    2016   BBWAA    440.0   330.0    0.0        N   Player
# 4119  lowelmi01    2016   BBWAA    440.0   330.0    0.0        N   Player
#
#      needed_note
# 0            NaN
# 1            NaN
# 2            NaN
# ...

# %%
MPlayer_file = "../Resources/master_player.csv"
MPlayer_file_df = pd.read_csv(MPlayer_file)
MPlayer_file_df
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0      aardsda01     1981.0        12.0      27.0          USA         CO
# 1      aaronha01     1934.0         2.0       5.0          USA         AL
# 2      aaronto01     1939.0         8.0       5.0          USA         AL
# 3       aasedo01     1954.0         9.0       8.0          USA         CA
# 4       abadan01     1972.0         8.0      25.0          USA         FL
# ...          ...        ...         ...       ...          ...        ...
# 18841   zupofr01     1939.0         8.0      29.0          USA         CA
# 18842  zuvelpa01     1958.0        10.0      31.0          USA         CA
# 18843  zuverge01     1924.0         8.0      20.0          USA         MI
# 18844  zwilldu01     1888.0        11.0       2.0          USA         MO
# 18845   zychto01     1990.0         8.0       7.0          USA         IL
#
#            birthCity  deathYear  deathMonth  deathDay  ...  nameLast  \
# ...

# %%
BAT_file = "../Resources/Batting.csv"
BAT_file_df = pd.read_csv(BAT_file)
BAT_file_df
# Out:
#          playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI  \
# 0       abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...   0.0
# 1        addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...  13.0
# 2       allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...  19.0
# 3       allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...  27.0
# 4       ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...  16.0
# ...           ...     ...    ...    ...  ...  ..  ...  ..  ..  ..  ...   ...
# 108784  zimmebr02    2020      1    BAL   AL   2    0   0   0   0  ...   0.0
# 108785  zimmejo02    2020      1    DET   AL   3    0   0   0   0  ...   0.0
# 108786  zimmeky01    2020      1    KCA   AL  16    0   0   0   0  ...   0.0
# 108787  zuberty01    2020      1    KCA   AL  23    0   0   0   0  ...   0.0
# 108788  zuninmi01    2020      1    TBA   AL  28   75   8  11   4  ...  10.0
#
# ...

# %%
pd.concat([HOF_file_df, MPlayer_file_df ])
# Out:
#         playerID  yearid votedBy  ballots  needed  votes inducted category  \
# 0       cobbty01  1936.0   BBWAA    226.0   170.0  222.0        Y   Player
# 1       ruthba01  1936.0   BBWAA    226.0   170.0  215.0        Y   Player
# 2      wagneho01  1936.0   BBWAA    226.0   170.0  215.0        Y   Player
# 3      mathech01  1936.0   BBWAA    226.0   170.0  205.0        Y   Player
# 4      johnswa01  1936.0   BBWAA    226.0   170.0  189.0        Y   Player
# ...          ...     ...     ...      ...     ...    ...      ...      ...
# 18841   zupofr01     NaN     NaN      NaN     NaN    NaN      NaN      NaN
# 18842  zuvelpa01     NaN     NaN      NaN     NaN    NaN      NaN      NaN
# 18843  zuverge01     NaN     NaN      NaN     NaN    NaN      NaN      NaN
# 18844  zwilldu01     NaN     NaN      NaN     NaN    NaN      NaN      NaN
# 18845   zychto01     NaN     NaN      NaN     NaN    NaN      NaN      NaN
#
# ...

# %%
BAT_file = "../Resources/Batting.csv"
BAT_file_df = pd.read_csv(BAT_file)
BAT_file_df

# %%
HOF_file_df.merge(MPlayer_file_df)
# Out:
#        playerID  yearid   votedBy  ballots  needed  votes inducted category  \
# 0      cobbty01    1936     BBWAA    226.0   170.0  222.0        Y   Player
# 1      ruthba01    1936     BBWAA    226.0   170.0  215.0        Y   Player
# 2     wagneho01    1936     BBWAA    226.0   170.0  215.0        Y   Player
# 3     wagneho01    1936  Veterans     78.0    59.0    5.0        N   Player
# 4     mathech01    1936     BBWAA    226.0   170.0  205.0        Y   Player
# ...         ...     ...       ...      ...     ...    ...      ...      ...
# 4114  grudzma01    2016     BBWAA    440.0   330.0    0.0        N   Player
# 4115  ausmubr01    2016     BBWAA    440.0   330.0    0.0        N   Player
# 4116  hamptmi01    2016     BBWAA    440.0   330.0    0.0        N   Player
# 4117  castilu01    2016     BBWAA    440.0   330.0    0.0        N   Player
# 4118  lowelmi01    2016     BBWAA    440.0   330.0    0.0        N   Player
#
# ...
